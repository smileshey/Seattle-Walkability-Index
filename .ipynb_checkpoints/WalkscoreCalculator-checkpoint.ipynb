# %%
import arcpy
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
gdb_path = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb"

# Set the workspace to the geodatabase
arcpy.env.workspace = gdb_path

# List all feature classes in the geodatabase
feature_classes = arcpy.ListFeatureClasses()
print("Feature Classes in the Geodatabase:")
for fc in feature_classes:
    print(fc)
# Out:
# Feature Classes in the Geodatabase:
# Polygons_2
# WorldImagery_DetectObjectsUs
# Polygons_2_1
# WorldImagery_DetectObjectsUs1
# Polygons_2_2
# WorldImagery_DetectObjectsUs2
# limits_JSONToFeatures
# citylimits_JSONToFeatures
# citylimits_JSONToFeatur_Clip
# Park_Boundarie_JSONToFeature
# Parks_Intersect
# Parks_Boundary_out_Intersect
# Polygons_2_3
# fishnet_park_Intersect
# fishnet_park_Inter_Intersect
# fishnet_park_Inter_Intersect1
# Walkability
# Polygons_2_4
# Polygons_2_5
# fishnet_inter
# citylimits
# fishnet_Intersect
# fishnet_Intersect1
# Parks_Boundary_out_Intersect1
# Park_Boundarie_JSONToFeature1
# Parks_SPR_Merge
# Parks_Merge_Intersect
# Parks_Merge_Intersect1
# fishnet_Intersect2
# Polygons_2_6
# Polygons_2_7
# Parks_Merge_Intersect2
# fishnet_sidewalk_intersect
# fishnet_sidewalks_Intersect
# Seattle_Streets
# Seattle_Streets_poly
# trails_Intersect
# fishnet_ExportFeatures
# fishnet_dataframe
# Streets_Intersect
# Bike_facilities
# shp
# Bike_facilities_BKF_BL
# Bike_facilities_BKF_CLMB
# Bike_facilities_BKF_OFFST
# Bike_facilities_BKF_SHW
# Bike_Greenways_Intersect
# Bike_protected_Intersect
# Bike_buffer_Intersect
# Streets_Intersect1
# Polygons_2_8
# fishnet_check
# fishnet_check_label
# fishnet_check_Clip
# Polygons_2_9
# fishnet__
# fishnet___label
# fishnet__Intersect
# Polygons_2_10
# fishnet_clipped_graveyard
# temp_fishnet_Universities
# Sidewalks_projected
# Sidewalks_intersect
# Universities_intersect
# temp_fishnet_joined
# temp_fishnet_initial
# Intersections
# fishnet_clipped_updated
# fishnet_clipped_Clip
# neighborhoodMap
# neighborhoodsMap
# Bike_greenways_proj
# Bike_protected_proj
# Bike_buffer_proj
# Healthy_Streets_proj
# Parks_proj
# Sidewalks_proj
# trails_proj
# MultiUseTrails_proj
# Streets_proj
# Industrial
# ParkingLots
# GolfCourse
# Cemeteries
# Hospitals
# Bike_greenways
# Bike_protected
# Bike_buffer
# Healthy_Streets
# Parks
# Universities
# Sidewalks
# Plaza
# trails
# MultiUseTrails
# Streets
# Marked_Crosswalks
# neighborhoods
# Polygons_2_11
# Polygons_2_12
# GreenLake
# Polygons_2_13
# Polygons_2_14
# fishnet
# fishnet_label
# fishnet_Clipped
# ParkingLots_clipped
# TrafficControlDevices_Clip
# TrafficControlDevices_clipped
# PointsofInterest
# Business_Amenities
# Public_Amenities
# Public_Amenities_proj
# Public_Amenities_int
# Business_Amenities_proj
# Business_Amenities_int
# walkscore_fishnet_clipped
# walkscore_neighborhoods_join
# walkscore_neighborhoods
# walkscore_fishnet
# Public_Amenities_intersect
# Business_Amenities_intersect
# Industrial_int
# ParkingLots_int
# GolfCourse_int
# Cemeteries_int
# Hospitals_int
# Bike_greenways_int
# Bike_protected_int
# Bike_buffer_int
# Healthy_Streets_int
# Parks_int
# Universities_int
# Sidewalks_int
# Plaza_int
# trails_int
# MultiUseTrails_int
# Streets_int

# %%
gdb_path = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb"
exported_fishnet_layer = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb\walkscore_fishnet"

# Set the workspace to the geodatabase
arcpy.env.workspace = gdb_path

# List all fields in the exported fishnet layer
fields = arcpy.ListFields(exported_fishnet_layer)

# Print field names and types
print("Field Names and Types:")
for field in fields:
    print(f"Name: {field.name}, Type: {field.type}, Alias: {field.aliasName}")
# Out:
# Field Names and Types:
# Name: OBJECTID, Type: OID, Alias: OID
# Name: Shape, Type: Geometry, Alias: Shape
# Name: IndexID, Type: Integer, Alias: IndexID
# Name: Shape_Length, Type: Double, Alias: Shape_Length
# Name: Shape_Area, Type: Double, Alias: Shape_Area
# Name: total_area, Type: Double, Alias: total_area
# Name: Industrial_SUM_Industrial_effective_area, Type: Double, Alias: Industrial_SUM_Industrial_effective_area
# Name: ParkingLots_SUM_ParkingLots_effective_area, Type: Double, Alias: ParkingLots_SUM_ParkingLots_effective_area
# Name: GolfCourse_SUM_GolfCourse_effective_area, Type: Double, Alias: GolfCourse_SUM_GolfCourse_effective_area
# Name: Cemeteries_SUM_Cemeteries_effective_area, Type: Double, Alias: Cemeteries_SUM_Cemeteries_effective_area
# Name: Hospitals_SUM_Hospitals_effective_area, Type: Double, Alias: Hospitals_SUM_Hospitals_effective_area
# Name: Slope_MEAN, Type: Double, Alias: Slope_MEAN
# Name: Bike_greenways_SUM_Bike_greenways_area, Type: Double, Alias: Bike_greenways_SUM_Bike_greenways_area
# Name: Bike_protected_SUM_Bike_protected_area, Type: Double, Alias: Bike_protected_SUM_Bike_protected_area
# Name: Bike_buffer_SUM_Bike_buffer_area, Type: Double, Alias: Bike_buffer_SUM_Bike_buffer_area
# Name: Healthy_Streets_SUM_Healthy_Streets_area, Type: Double, Alias: Healthy_Streets_SUM_Healthy_Streets_area
# Name: Parks_SUM_Parks_area, Type: Double, Alias: Parks_SUM_Parks_area
# Name: Universities_SUM_Universities_area, Type: Double, Alias: Universities_SUM_Universities_area
# Name: Sidewalks_SUM_Sidewalks_area, Type: Double, Alias: Sidewalks_SUM_Sidewalks_area
# Name: Plaza_SUM_Plaza_area, Type: Double, Alias: Plaza_SUM_Plaza_area
# Name: trails_SUM_trails_area, Type: Double, Alias: trails_SUM_trails_area
# Name: MultiUseTrails_SUM_MultiUseTrails_area, Type: Double, Alias: MultiUseTrails_SUM_MultiUseTrails_area
# Name: Streets_SUM_Streets_effective_area, Type: Double, Alias: Streets_SUM_Streets_effective_area
# Name: business_density, Type: Double, Alias: business_density
# Name: public_density, Type: Double, Alias: public_density

# %%
field_list = []
slope_field = "Slope_MEAN"

# %%
for field in arcpy.ListFields(exported_fishnet_layer):
    if "area" in field.name.lower() and field.name.lower() != "shape_area":
        field_list.append(field.name)

# Print the populated field_list
print("fields in walkscore_fishnet:")
for field in field_list:
    print(field)
field_list.append(slope_field)  # Add slope field to the list
# Out:
# fields in walkscore_fishnet:
# total_area
# Industrial_SUM_Industrial_effective_area
# ParkingLots_SUM_ParkingLots_effective_area
# GolfCourse_SUM_GolfCourse_effective_area
# Cemeteries_SUM_Cemeteries_effective_area
# Hospitals_SUM_Hospitals_effective_area
# Bike_greenways_SUM_Bike_greenways_area
# Bike_protected_SUM_Bike_protected_area
# Bike_buffer_SUM_Bike_buffer_area
# Healthy_Streets_SUM_Healthy_Streets_area
# Parks_SUM_Parks_area
# Universities_SUM_Universities_area
# Sidewalks_SUM_Sidewalks_area
# Plaza_SUM_Plaza_area
# trails_SUM_trails_area
# MultiUseTrails_SUM_MultiUseTrails_area
# Streets_SUM_Streets_effective_area

# %%
def normalize_field(layer, field_name, norm_field_name, inverse=False, fill_null_value=None):
    try:
        # Calculate min and max values for the specified field
        with arcpy.da.SearchCursor(layer, [field_name]) as cursor:
            values = [row[0] for row in cursor if row[0] is not None]
            if not values:
                print(f"No values found for {field_name}. Skipping normalization.")
                return
            min_value = min(values)
            max_value = max(values)
        
        # Add new field for normalized values if it does not already exist
        if not any(f.name == norm_field_name for f in arcpy.ListFields(layer)):
            arcpy.management.AddField(layer, norm_field_name, "DOUBLE")
        
        # Normalize the data and store in the new field
        with arcpy.da.UpdateCursor(layer, [field_name, norm_field_name]) as cursor:
            for row in cursor:
                if row[0] is not None:
                    normalized_value = (row[0] - min_value) / (max_value - min_value)
                    if inverse:
                        normalized_value = 1 - normalized_value
                    row[1] = normalized_value
                else:
                    row[1] = fill_null_value if fill_null_value is not None else None
                cursor.updateRow(row)
        print(f"Normalization complete for {field_name}.")
    except Exception as e:
        print(f"Error processing field {field_name}: {e}")

# %%
for field in field_list:
    norm_field = "NORM_" + field
    if field == slope_field:
        normalize_field(walkscore_fishnet, 'Slope_Mean', 'NORM_Slope_Mean', inverse=True, fill_null_value=1)
    else:
        normalize_field(walkscore_fishnet, field, norm_field)
# Out:
# Normalization complete for total_area.
# Normalization complete for Industrial_SUM_Industrial_effective_area.
# Normalization complete for ParkingLots_SUM_ParkingLots_effective_area.
# Normalization complete for GolfCourse_SUM_GolfCourse_effective_area.
# Normalization complete for Cemeteries_SUM_Cemeteries_effective_area.
# Normalization complete for Hospitals_SUM_Hospitals_effective_area.
# Normalization complete for Bike_greenways_SUM_Bike_greenways_area.
# Normalization complete for Bike_protected_SUM_Bike_protected_area.
# Normalization complete for Bike_buffer_SUM_Bike_buffer_area.
# Normalization complete for Healthy_Streets_SUM_Healthy_Streets_area.
# Normalization complete for Parks_SUM_Parks_area.
# Normalization complete for Universities_SUM_Universities_area.
# Normalization complete for Sidewalks_SUM_Sidewalks_area.
# Normalization complete for Plaza_SUM_Plaza_area.
# Normalization complete for trails_SUM_trails_area.
# Normalization complete for MultiUseTrails_SUM_MultiUseTrails_area.
# Normalization complete for Streets_SUM_Streets_effective_area.
# Normalization complete for Slope_Mean.

# %% [markdown]
# # Calculating Walkscore

# %% [markdown]
# #### Setup

# %%
sidewalk_score_field = 'sidewalk_score'
park_score_field = 'park_score'
trail_score_field = 'trail_score'
street_score_field = 'street_score'
bike_score_field = 'bike_score'
walkscore_field = 'walk_score'
unadjusted_walkscore_field = 'unadjusted_walkscore'
slope_field = "Slope_MEAN"

# %%
positive_weights = {
    sidewalk_score_field: 0.55,
    park_score_field: 0.1,
    trail_score_field: 0.3,
    bike_score_field: 0.05
}

# %%
negative_weights = {
    "effective_area_scaler": 1,
}

# %%
assert abs(sum(positive_weights.values()) - 1.0) < 1e-6, "The positive weights must sum up to 1.0"

# %%
for score_field in [walkscore_field,sidewalk_score_field,park_score_field,trail_score_field,street_score_field,bike_score_field,unadjusted_walkscore_field]:
    if not any(f.name == score_field for f in arcpy.ListFields(walkscore_fishnet)):
        arcpy.management.AddField(walkscore_fishnet, score_field, "DOUBLE")

# %% [markdown]
# ### Slope Scaler
#
# As part of the data, we have a slope element that describes how steep the slope is within each fishnet grid. Instead of handling this element like the others, I'd like to implement a custom function that will allow me to more readily customize the output of the slope scaler.

# %%
with arcpy.da.UpdateCursor(walkscore_fishnet, [slope_field]) as cursor:
    for row in cursor:
        if row[0] is None:
            row[0] = 0
        cursor.updateRow(row)

print("Populated null values in Slope_Mean field with 0.")
# Out:
# Populated null values in Slope_Mean field with 0.

# %%
# Field containing the slope values
slope_field = "Slope_Mean"

# List to store slope values
slope_values = []

# Extract slope values
with arcpy.da.SearchCursor(exported_fishnet_layer, [slope_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            slope_values.append(row[0])

print(f"Extracted {len(slope_values)} slope values.")
# Out:
# Extracted 31701 slope values.

# %%
slope_series = pd.Series(slope_values)
slope_stats = slope_series.describe()
print("Descriptive Statistics for Slope Values:")
print(slope_stats)
# Out:
# Descriptive Statistics for Slope Values:
# count    31701.000000
# mean         5.009523
# std          4.656576
# min          0.000000
# 25%          1.833370
# 50%          3.612894
# 75%          6.744153
# max         44.830341
# dtype: float64

# %%
def get_slope_scaler(slope_value):
    if slope_value is None or slope_value < 0:
        return 1.0
    elif slope_value < 2:
        return 1.0
    elif 2 <= slope_value < 3:
        return 0.95
    elif 3 <= slope_value < 4:
        return 0.9
    elif 4 <= slope_value < 5:
        return 0.7
    elif 5 <= slope_value < 7:
        return 0.5
    elif 7 <= slope_value < 10:
        return 0.3
    elif 10 <= slope_value < 15:
        return 0.1
    elif 15 <= slope_value < 20:
        return 0.05
    elif 20 <= slope_value < 25:
        return 0.02
    else:
        return 0.0

# %% [markdown]
# ### Streets, ParkingLots, and Industrial Scaler Values
#
# In the previous sheet, I created "effective areas" for each of Streets, Industrial, and Parkinglots. These effective area represent the area of surface streets in each fishnet grid multiplied by the speed limit on each street. Since Industrial and Parklots don't have explicit speed limits, I've set a universal speed value of 15 and used this to calculate the effective area.
#
# Below, I'll create a scaler value based on the sum of all three effective area fields.

# %%
streets_field = "Streets_SUM_Streets_effective_area"
industrial_field = "Industrial_SUM_Industrial_effective_area"
parkinglots_field = "ParkingLots_SUM_Parkinglots_effective_area"

# %%
combined_values = []

# %%
with arcpy.da.SearchCursor(exported_fishnet_layer, [streets_field, industrial_field, parkinglots_field]) as cursor:
    for row in cursor:
        combined_value = (row[0] if row[0] is not None else 0) + \
                         (row[1] if row[1] is not None else 0) + \
                         (row[2] if row[2] is not None else 0)
        combined_values.append(combined_value)

print(f"Extracted {len(combined_values)} combined values.")
# Out:
# Extracted 31701 combined values.

# %%
combined_series = pd.Series(combined_values)
combined_stats = combined_series.describe()
print("Descriptive Statistics for Combined Values:")
print(combined_stats)
# Out:
# Descriptive Statistics for Combined Values:
# count    3.170100e+04
# mean     3.357458e+05
# std      4.682427e+05
# min      0.000000e+00
# 25%      1.105532e+05
# 50%      1.988975e+05
# 75%      3.749907e+05
# max      9.653101e+06
# dtype: float64

# %%
combined_series.isna().sum()
# Out:
# 0

# %%
mean_combined = combined_stats['mean']
std_combined = combined_stats['std']

def normalize_combined_value(combined_value):
    return (combined_value - mean_combined) / std_combined

# %%
def get_effective_area_scaler(combined_value):
    if combined_value is None:
        return 1.0
    else:
        normalized_value = normalize_combined_value(combined_value)
        decay_rate = 20  # Adjust as needed for a more gradual effect
        return 1 / (1 + math.exp(decay_rate * normalized_value))

# %%
# #### TO RUN THIS, COMMENT OUT DECAY RATE IN THE ABOVE FUNCTION & REMOVE DECAY RATE FROM THE INPUTS
# min_value = 0
# max_value = 9653101
# percentile_25 = 110553.2
# percentile_75 = 374990.7

# # Adjust linspace to focus more on the range between 25th and 75th percentile
# combined_values = np.linspace(min_value, max_value, 1000)

# # Decay rates to visualize
# decay_rates = [.1,.5,1.0,2,3,4,5,6,7,8,9,10,20]

# # Plot the scaler values for different decay rates
# plt.figure(figsize=(10, 6))

# for decay_rate in decay_rates:
#     scaler_values = [get_effective_area_scaler(value, decay_rate) for value in combined_values]
#     plt.plot(combined_values, scaler_values, label=f"Decay Rate = {decay_rate}")

# plt.xlabel('Combined Value')
# plt.ylabel('Scaler Value')
# plt.title('Effect of Decay Rate on Effective Area Scaler')
# plt.legend()
# plt.grid(True)
# plt.xlim(percentile_25, percentile_75)  # Focus on the range between 25th and 75th percentile
# plt.show()

# %% [markdown]
# #### Business Density Scaler

# %%
business_density = 'business_density'

# %%
# List to store slope values
business_values = []

# Extract slope values
with arcpy.da.SearchCursor(exported_fishnet_layer, [business_density]) as cursor:
    for row in cursor:
        if row[0] is not None:
            business_values.append(row[0])

print(f"Extracted {len(business_values)} business density values.")
# Out:
# Extracted 31701 business density values.

# %%
business_series = pd.Series(business_values)
business_density_stats = business_series.describe()
print("Descriptive Statistics for Business Values:")
print(business_density_stats)
# Out:
# Descriptive Statistics for Business Values:
# count    31701.000000
# mean         0.000022
# std          0.000126
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.003659
# dtype: float64

# %% [markdown]
# From the distribution above, we can see that the majority of values are 0. This indicates that most fishnet grids don't have a business in them.
#
# Because of this distribution, I'd like to reward fishnet grids that contain businesses and set the minimum scaler to 1. Below I'll adjust the business density scaler to reflect this, using 1 as the minimum and 2 as the maximum.

# %%
def normalize_business_density(business_density_value):
    mean_business_density = business_density_stats['mean']
    std_business_density = business_density_stats['std']
    return (business_density_value - mean_business_density) / std_business_density

# %%
def get_business_density_scaler(business_density_value):
    if business_density_value is None or business_density_value <= 0:
        return 1.0
    elif business_density_value >= 0.0015:
        return 2.0
    else:
        # Linearly interpolate between 1 and 2 for values between 0 and 0.00428
        return 1.0 + (business_density_value / 0.0015)

# %% [markdown]
# #### Public Amenity Density Scaler

# %%
public_amenity_density = 'public_density'

# %%
# List to store slope values
public_amenity_values = []

# Extract slope values
with arcpy.da.SearchCursor(exported_fishnet_layer, [public_amenity_density]) as cursor:
    for row in cursor:
        if row[0] is not None:
            public_amenity_values.append(row[0])

print(f"Extracted {len(public_amenity_values)} Public Amenity Density values.")
# Out:
# Extracted 31701 Public Amenity Density values.

# %%
public_amenity_series = pd.Series(public_amenity_values)
public_amenity_density_stats = public_amenity_series.describe()
print("Descriptive Statistics for Public Amenity Density Values:")
print(public_amenity_density_stats)
# Out:
# Descriptive Statistics for Public Amenity Density Values:
# count    31701.000000
# mean         0.000034
# std          0.000224
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.015842
# dtype: float64

# %%
def normalize_public_amenity_density(public_amenity_density_value):
    mean_public_amenity_density = public_amenity_density_stats['mean']
    std_public_amenity_density = public_amenity_density_stats['std']
    return (public_amenity_density_value - mean_public_amenity_density) / std_public_amenity_density

# %%
def get_public_amenity_density_scaler(public_amenity_density_value):
    if public_amenity_density_value is None or public_amenity_density_value <= 0:
        return 1.0
    elif public_amenity_density_value >= 0.00428:
        return 1.5
    else:
        # Linearly interpolate between 1 and 1.5 for values between 0 and 0.00428
        return 1.0 + (0.5 * public_amenity_density_value / 0.00428)

# %% [markdown]
# ### Creating Scaler Fields for Troubleshooting

# %%
scaler_fields = {
    'slope_scaler': 'slope_scaler',
    'effective_area_scaler': 'effective_area_scaler',
    'business_density_scaler': 'business_density_scaler',
    'public_amenity_density_scaler': 'public_amenity_density_scaler'
}

# %%
industrial_field = "Industrial_SUM_Industrial_effective_area"
golfcourses_field = "GolfCourse_SUM_GolfCourse_effective_area"
hospitals_field = "Hospitals_SUM_Hospitals_effective_area"
cemeteries_field = "Cemeteries_SUM_Cemeteries_effective_area"

parkinglots_field = "ParkingLots_SUM_Parkinglots_effective_area"
streets_field = "Streets_SUM_Streets_effective_area"
slope_field = "Slope_MEAN"
walkscore_field = "walk_score"
unadjusted_walkscore_field = "unadjusted_walkscore"
public_amenity_density_field = 'public_density'
business_density_field = 'business_density'

# %%
score_fields = [sidewalk_score_field, park_score_field, trail_score_field, bike_score_field, walkscore_field, unadjusted_walkscore_field]
amenities_fields = [business_density, public_amenity_density]

# %%
fields = [streets_field, industrial_field, golfcourses_field, hospitals_field, cemeteries_field, parkinglots_field, slope_field, walkscore_field] + list(scaler_fields.values())+ list(score_fields)+list(amenities_fields)

# %%
fields
# Out:
# ['Streets_SUM_Streets_effective_area', 'Industrial_SUM_Industrial_effective_area', 'GolfCourse_SUM_GolfCourse_effective_area', 'Hospitals_SUM_Hospitals_effective_area', 'Cemeteries_SUM_Cemeteries_effective_area', 'ParkingLots_SUM_Parkinglots_effective_area', 'Slope_MEAN', 'walk_score', 'slope_scaler', 'effective_area_scaler', 'business_density_scaler', 'public_amenity_density_scaler', 'sidewalk_score', 'park_score', 'trail_score', 'bike_score', 'walk_score', 'unadjusted_walkscore', 'business_density', 'public_density']

# %%
# Add new scaler fields if they don't exist
for field_name in scaler_fields.values():
    if not any(f.name == field_name for f in arcpy.ListFields(walkscore_fishnet)):
        arcpy.management.AddField(walkscore_fishnet, field_name, "DOUBLE")

# %%
# Update scalers in walkscore_fishnet
with arcpy.da.UpdateCursor(walkscore_fishnet, fields) as cursor:
    for row in cursor:
        slope_value = row[fields.index(slope_field)]
        streets_value = row[fields.index(streets_field)]
        industrial_value = row[fields.index(industrial_field)]
        parkinglots_value = row[fields.index(parkinglots_field)]
        golfcourses_value = row[fields.index(golfcourses_field)]
        hospitals_value = row[fields.index(hospitals_field)]
        cemeteries_value = row[fields.index(cemeteries_field)]
        business_density_value = row[fields.index(business_density_field)]
        public_amenity_density_value = row[fields.index(public_amenity_density_field)]

        combined_value = (streets_value if streets_value is not None else 0) + \
                         (industrial_value if industrial_value is not None else 0) + \
                         (parkinglots_value if parkinglots_value is not None else 0) + \
                         (golfcourses_value if golfcourses_value is not None else 0) + \
                         (hospitals_value if hospitals_value is not None else 0) + \
                         (cemeteries_value if cemeteries_value is not None else 0)
        
        slope_scaler = get_slope_scaler(slope_value)
        effective_area_scaler = get_effective_area_scaler(combined_value)
        business_density_scaler = get_business_density_scaler(business_density_value)
        public_amenity_density_scaler = get_public_amenity_density_scaler(public_amenity_density_value)

        row[fields.index(scaler_fields['slope_scaler'])] = slope_scaler
        row[fields.index(scaler_fields['effective_area_scaler'])] = effective_area_scaler
        row[fields.index(scaler_fields['business_density_scaler'])] = business_density_scaler
        row[fields.index(scaler_fields['public_amenity_density_scaler'])] = public_amenity_density_scaler
        
        cursor.updateRow(row)

print("Scaler values updated and stored in walkscore_fishnet.")
# Out:
# Scaler values updated and stored in walkscore_fishnet.

# %% [markdown]
# ### Score Component Definitions

# %%
sidewalk_score_components = ['NORM_Sidewalks_SUM_Sidewalks_area',"NORM_Plaza_SUM_Plaza_area"]
park_score_components = ['NORM_Parks_SUM_parks_area', 'NORM_Universities_SUM_Universities_area']
trail_score_components = ['NORM_trails_SUM_trails_area','NORM_MultiUseTrails_SUM_MultiUseTrails_area']
bike_score_components = ['NORM_Bike_greenways_SUM_Bike_greenways_area',
                         'NORM_Bike_protected_SUM_Bike_protected_area',
                         'NORM_Bike_buffer_SUM_Bike_buffer_area',
                         'NORM_Healthy_Streets_SUM_Healthy_Streets_area']
street_score_components = ['NORM_Streets_SUM_Streets_effective_area']
slope_component = [slope_field]

# %%
walkscore_fields = (sidewalk_score_components + park_score_components + trail_score_components +
          bike_score_components + street_score_components + slope_component +
          score_fields + list(scaler_fields.values()))

# %%
for field_name in [walkscore_field, unadjusted_walkscore_field]:
    if not any(f.name == field_name for f in arcpy.ListFields(walkscore_fishnet)):
        arcpy.management.AddField(walkscore_fishnet, field_name, "DOUBLE")
        walkscore_fields.append(field_name)  # Add the new field to the list

# %%
# Calculate walkscore using the effective area scaler
with arcpy.da.UpdateCursor(walkscore_fishnet, walkscore_fields) as cursor:
    for row in cursor:
        # Calculate individual scores
        sidewalk_score = sum(row[walkscore_fields.index(component)] for component in sidewalk_score_components if row[walkscore_fields.index(component)] is not None)
        park_score = sum(row[walkscore_fields.index(component)] for component in park_score_components if row[walkscore_fields.index(component)] is not None)
        trail_score = sum(row[walkscore_fields.index(component)] for component in trail_score_components if row[walkscore_fields.index(component)] is not None)
        bike_score = sum(row[walkscore_fields.index(component)] for component in bike_score_components if row[walkscore_fields.index(component)] is not None)

        row[walkscore_fields.index(sidewalk_score_field)] = sidewalk_score
        row[walkscore_fields.index(park_score_field)] = park_score
        row[walkscore_fields.index(trail_score_field)] = trail_score
        row[walkscore_fields.index(bike_score_field)] = bike_score

        slope_scaler = row[walkscore_fields.index(scaler_fields['slope_scaler'])]
        effective_area_scaler = row[walkscore_fields.index(scaler_fields['effective_area_scaler'])]
        business_density_scaler = row[walkscore_fields.index(scaler_fields['business_density_scaler'])]
        public_amenity_density_scaler = row[walkscore_fields.index(scaler_fields['public_amenity_density_scaler'])]

        # Calculate positive component of the walkscore (unadjusted walkscore)
        walkscore_positive = sum(row[walkscore_fields.index(field)] * positive_weights[field] for field in score_fields if row[walkscore_fields.index(field)] is not None)

        # Debugging statements
        print(f"Walkscore Positive: {walkscore_positive}")
        print(f"Effective Area Scaler: {effective_area_scaler}")
        print(f"Slope Scaler: {slope_scaler}")
        print(f"Business Density Scaler: {business_density_scaler}")
        print(f"Public Amenity Density Scaler: {public_amenity_density_scaler}")

        # Assign the unadjusted walkscore to the unadjusted_walkscore field
        row[walkscore_fields.index(unadjusted_walkscore_field)] = walkscore_positive

        # Calculate final walkscore with scalers applied
        walkscore = walkscore_positive * effective_area_scaler * slope_scaler * business_density_scaler * public_amenity_density_scaler

        # Debugging statement
        print(f"Calculated Walkscore: {walkscore}")

        # Assign the calculated walkscore to the walkscore field explicitly
        row[walkscore_fields.index(walkscore_field)] = walkscore
        
        cursor.updateRow(row)

print("Aggregated and scaled walkscore calculation complete.")
# Out:
# Walkscore Positive: 0.021746899004593135
# Effective Area Scaler: 0.9998913680336873
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.015221175617335143
# Walkscore Positive: 0.05669963378977255
# Effective Area Scaler: 9.196495165081582e-05
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 4.953660126090626e-06
# Walkscore Positive: 0.05458276528118631
# Effective Area Scaler: 2.0792509031497543e-24
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.078167008069518e-25
# Walkscore Positive: 0.17711390550888786
# Effective Area Scaler: 6.225636378826868e-20
# Slope Scaler: 1.0
# Business Density Scaler: 1.0937541254510035
# Public Amenity Density Scaler: 1.0164288771234236
# Calculated Walkscore: 1.225838084863332e-20
# Walkscore Positive: 0.035171848538220446
# Effective Area Scaler: 0.9724765859024563
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01710189959316346
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.13308826985848682
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.013308819114232104
# Walkscore Positive: 0.00955782427268377
# Effective Area Scaler: 0.9998673408920712
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009556556340242014
# Walkscore Positive: 0.04765990955748228
# Effective Area Scaler: 0.9987925419202074
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.014280708664381473
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.020986908542170675
# Effective Area Scaler: 0.9997794649038236
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.006294684057683065
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.023103777786089946
# Effective Area Scaler: 0.025254650401808656
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0005834778309487743
# Walkscore Positive: 0.03040423864038176
# Effective Area Scaler: 0.16964828554726297
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0015474080876131833
# Walkscore Positive: 0.020988988388643992
# Effective Area Scaler: 0.9997793354772742
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.020984356863538715
# Walkscore Positive: 0.031805150449993984
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.003180513163857283
# Walkscore Positive: 0.033635255774923024
# Effective Area Scaler: 0.9925029416133186
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.033383090298527464
# Walkscore Positive: 0.04052757408959404
# Effective Area Scaler: 2.058150277146938e-05
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 8.341183784459103e-07
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999947224485103
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.222110045779714
# Effective Area Scaler: 0.9864670125302263
# Slope Scaler: 0.5
# Business Density Scaler: 1.0939512846904969
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.11984467875708699
# Walkscore Positive: 0.0034196700574516134
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.001025900410457782
# Walkscore Positive: 0.05672660237849842
# Effective Area Scaler: 0.9420084552342046
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.04809324516952883
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.0450885481936007e-17
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.045506526759524435
# Effective Area Scaler: 0.9973873275704697
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.04538763311169614
# Walkscore Positive: 0.015370957900022835
# Effective Area Scaler: 0.9999960094456981
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.004611268968414199
# Walkscore Positive: 0.005635602943619462
# Effective Area Scaler: 0.9999703545369828
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.005635435873560818
# Walkscore Positive: 0.02185547618882602
# Effective Area Scaler: 0.998855306697918
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0152813208601332
# Walkscore Positive: 0.020713847178883055
# Effective Area Scaler: 0.0001142038115312793
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.655920209513417e-06
# Walkscore Positive: 0.05484328195616739
# Effective Area Scaler: 6.924037237803025e-08
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0603341784000504
# Calculated Walkscore: 3.825156398780019e-09
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999157266738334
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.15929985561862536
# Effective Area Scaler: 0.994808144967886
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0329467320596883
# Calculated Walkscore: 0.1555092568127394
# Walkscore Positive: 0.03569690516540903
# Effective Area Scaler: 0.9283390996973107
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03148189116307429
# Walkscore Positive: 0.06326959052874992
# Effective Area Scaler: 0.9932301632859953
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.06284126573190835
# Walkscore Positive: 0.028239465497259288
# Effective Area Scaler: 0.8806259192952341
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.023624985000733505
# Walkscore Positive: 0.03757025681605089
# Effective Area Scaler: 0.9997864753175325
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03380601117500462
# Walkscore Positive: 0.03576679475298797
# Effective Area Scaler: 0.9997823202737379
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03218310814220718
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.031423964321268e-15
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.010387582345595961
# Effective Area Scaler: 0.9999784321431756
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00519367915385359
# Walkscore Positive: 0.01569745795769036
# Effective Area Scaler: 0.9966571654055353
# Slope Scaler: 0.02
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0003128996790436847
# Walkscore Positive: 0.0
# Effective Area Scaler: 6.66446938840781e-07
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.005411858069303301
# Effective Area Scaler: 0.9992524933106842
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0016223438007584607
# Walkscore Positive: 0.005652213784472933
# Effective Area Scaler: 0.9999986050789933
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0028261029500405957
# Walkscore Positive: 0.026402756427276946
# Effective Area Scaler: 0.9999615365024747
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.026401740884920442
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.0013360156873142143
# Slope Scaler: 0.95
# Business Density Scaler: 1.2064569324391352
# Public Amenity Density Scaler: 1.036178200777886
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.16155373985806332
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0658707707155084
# Calculated Walkscore: 0.17219530736807762
# Walkscore Positive: 0.037698941321847534
# Effective Area Scaler: 0.2016061900345331
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.007600339928233106
# Walkscore Positive: 0.025143905534176926
# Effective Area Scaler: 0.9997815572989401
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.022624571728383162
# Walkscore Positive: 0.027210421130879264
# Effective Area Scaler: 0.03385906029105577
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0004606596448077295
# Walkscore Positive: 0.045397324717685754
# Effective Area Scaler: 0.9811907728199631
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02227171806185245
# Walkscore Positive: 0.0359507766135526
# Effective Area Scaler: 0.9759417486622654
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.035085863793997
# Walkscore Positive: 0.11951343687959361
# Effective Area Scaler: 0.28870701636654245
# Slope Scaler: 1.0
# Business Density Scaler: 1.0940704057767618
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03775020765509215
# Walkscore Positive: 0.016027979624970892
# Effective Area Scaler: 0.9998428578004223
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01602546095299784
# Walkscore Positive: 0.12286529753666443
# Effective Area Scaler: 0.3829328919230633
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0446967055175674
# Walkscore Positive: 0.010578026686798248
# Effective Area Scaler: 0.8134621427337907
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.049313578072451
# Calculated Walkscore: 0.004514579463607005
# Walkscore Positive: 0.023390439772532034
# Effective Area Scaler: 9.347710656696843e-09
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.5305294418856634e-10
# Walkscore Positive: 0.13192881060242484
# Effective Area Scaler: 0.9994073195099394
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.09229543327921272
# Walkscore Positive: 0.09762953009403785
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.09762947235023907
# Walkscore Positive: 0.0
# Effective Area Scaler: 7.694708772223635e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0012396103696759642
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0006198048182490429
# Walkscore Positive: 0.0
# Effective Area Scaler: 9.168416113684031e-16
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.19100067535880244
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02506842098111935
# Effective Area Scaler: 0.9997853907163314
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012531520532624945
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.0513349352853725e-67
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02099880278458084
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.020998790364664024
# Walkscore Positive: 0.034174036903066564
# Effective Area Scaler: 0.9517414778149327
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.030898605965775285
# Walkscore Positive: 0.12298064080995622
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.12298056807203184
# Walkscore Positive: 0.11040710380746555
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.10488668658095114
# Walkscore Positive: 0.08866216176059512
# Effective Area Scaler: 0.990625279849349
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.08783097880613779
# Walkscore Positive: 0.06139604850803966
# Effective Area Scaler: 0.0020923645548065846
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00012846291570340788
# Walkscore Positive: 0.019573525723023316
# Effective Area Scaler: 0.15771371252583186
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0015435067044989373
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998280592382333
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04681195537798856
# Effective Area Scaler: 0.999768819434213
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03276079335456108
# Walkscore Positive: 0.02088192054763144
# Effective Area Scaler: 0.0005888130977927347
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.1065993492961364e-05
# Walkscore Positive: 0.21265479797794637
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.21265467220149478
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9812841880727629
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.02
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.10564778377511501
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0164605825142994
# Calculated Walkscore: 0.10738674432257618
# Walkscore Positive: 0.006011166874727483
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0006011163319372766
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9997984892831664
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02502892884055025
# Effective Area Scaler: 0.8848674273480093
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0022147283872414095
# Walkscore Positive: 0.037919882722824386
# Effective Area Scaler: 0.8920227955242923
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03044285981313041
# Walkscore Positive: 0.029043892074059285
# Effective Area Scaler: 0.0021232149535831838
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.8499927788569635e-05
# Walkscore Positive: 0.03818487707811563
# Effective Area Scaler: 0.9491370430468477
# Slope Scaler: 0.9
# Business Density Scaler: 1.3945605963772383
# Public Amenity Density Scaler: 1.0691402914212451
# Calculated Walkscore: 0.048633431781467534
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999930790833569
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.029560210557672384
# Effective Area Scaler: 0.9282192553750349
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.019206849642800332
# Walkscore Positive: 0.03418940570319858
# Effective Area Scaler: 3.2656954748444328e-06
# Slope Scaler: 0.95
# Business Density Scaler: 1.0940541493284917
# Public Amenity Density Scaler: 1.0164814514010208
# Calculated Walkscore: 1.1795846629323127e-07
# Walkscore Positive: 0.04392685764992489
# Effective Area Scaler: 0.9268671860939014
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03664292664953992
# Walkscore Positive: 0.004258487743887374
# Effective Area Scaler: 0.9608881363124667
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.003682737316560078
# Walkscore Positive: 0.01303538994887675
# Effective Area Scaler: 0.7826355538557944
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0005100979816182705
# Walkscore Positive: 0.11752217723330652
# Effective Area Scaler: 0.9999979093578092
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03525657946094533
# Walkscore Positive: 0.02512873973527454
# Effective Area Scaler: 0.9998281332040465
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.023868199892325394
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.5542919575504303
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02506752826618233
# Effective Area Scaler: 0.9999339798268146
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012532936651812434
# Walkscore Positive: 0.04291495329092707
# Effective Area Scaler: 0.18472261063087253
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.007530994096651902
# Walkscore Positive: 0.034632776642548116
# Effective Area Scaler: 0.9997865428902861
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.017312692015072316
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998948235504025
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.11358667967355508
# Effective Area Scaler: 0.9768475308148825
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03328706027177198
# Walkscore Positive: 0.0
# Effective Area Scaler: 8.590166113002445e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.024670365423044897
# Effective Area Scaler: 9.138327439209166e-08
# Slope Scaler: 0.3
# Business Density Scaler: 1.0941490349625898
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 7.400141671890098e-10
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.010545599001890782
# Effective Area Scaler: 0.9999945466214364
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0031636624478241734
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9921169425021312
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02910019652827483
# Effective Area Scaler: 0.4642712835833904
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012834866314975523
# Walkscore Positive: 0.02512827825392108
# Effective Area Scaler: 0.9997823496344318
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02386666862122436
# Walkscore Positive: 0.05023775242099287
# Effective Area Scaler: 0.5165214301871249
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02465143194338404
# Walkscore Positive: 0.0
# Effective Area Scaler: 8.327662017673706e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.033966701911771556
# Effective Area Scaler: 0.293186899286271
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0009958592012493355
# Walkscore Positive: 0.03465344303170314
# Effective Area Scaler: 0.9261289658193073
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.016046778678514752
# Walkscore Positive: 0.11441465470314682
# Effective Area Scaler: 7.156848456601642e-19
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 7.779059276785847e-20
# Walkscore Positive: 0.04174693241844041
# Effective Area Scaler: 0.01577435049114454
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0004609715207290224
# Walkscore Positive: 0.18672578471839613
# Effective Area Scaler: 0.0001876932354927397
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 3.5047166683716548e-06
# Walkscore Positive: 0.03546817576353632
# Effective Area Scaler: 0.9997813833086137
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.017730210914150696
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.661400854412621e-13
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.038091889130079694
# Effective Area Scaler: 0.9999383640115759
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.003808954129884222
# Walkscore Positive: 0.06444428758461793
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01933327484055217
# Walkscore Positive: 0.04574765467359608
# Effective Area Scaler: 2.148791512533957e-06
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 9.338706347690978e-08
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.00594809850791658
# Effective Area Scaler: 0.999895041657621
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.005352726784821194
# Walkscore Positive: 0.040778977006360614
# Effective Area Scaler: 0.8623457370291879
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.024615903887292446
# Walkscore Positive: 0.04538685319345982
# Effective Area Scaler: 0.12565029838003125
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.005132584481660011
# Walkscore Positive: 0.020885509139852126
# Effective Area Scaler: 0.9998306809041365
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.010440986412163959
# Walkscore Positive: 0.050589031588740625
# Effective Area Scaler: 8.620459648917653e-09
# Slope Scaler: 0.7
# Business Density Scaler: 1.2815538427039437
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 3.912205744473345e-10
# Walkscore Positive: 0.04614427156047589
# Effective Area Scaler: 0.9268783745967429
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.038493114678832145
# Walkscore Positive: 0.14130613377973567
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.07065302510152291
# Walkscore Positive: 0.045399739661430516
# Effective Area Scaler: 0.9529393188035409
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0411000371374806
# Walkscore Positive: 0.0986669181509532
# Effective Area Scaler: 0.9998057687952745
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.029594326186972254
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998671859037263
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.025184106129800973
# Effective Area Scaler: 0.9997794744454551
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012589276195415491
# Walkscore Positive: 0.019189025787324072
# Effective Area Scaler: 2.4314387239937934e-20
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0164520560882286
# Calculated Walkscore: 4.742454297497013e-23
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.023458859814122036
# Effective Area Scaler: 0.999786759534779
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02345385743594172
# Walkscore Positive: 0.03515240504614843
# Effective Area Scaler: 0.9810544471838352
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03448642329973141
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999334395394252
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.03181368348472472
# Effective Area Scaler: 0.9944735871689215
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03163786793611087
# Walkscore Positive: 0.03650169298336173
# Effective Area Scaler: 0.9991941810785484
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03464866526706618
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9996682669684929
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.03478420925317608
# Effective Area Scaler: 0.9999982901012833
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.034784149775701316
# Walkscore Positive: 0.13206086004971587
# Effective Area Scaler: 0.012240624124869969
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0008082536747378144
# Walkscore Positive: 0.025051954160356268
# Effective Area Scaler: 0.9997862198463163
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.007513979564923737
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999480675535201
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.012083060701992844
# Effective Area Scaler: 2.1510620182817573e-11
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 2.5991412940649715e-13
# Walkscore Positive: 0.0
# Effective Area Scaler: 3.8062699425847205e-08
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04733714285449449
# Effective Area Scaler: 0.0009105713211649807
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.2931153412757741e-05
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.5156106227059932e-14
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.020877249213814925
# Effective Area Scaler: 0.999786182426678
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.014610949703735271
# Walkscore Positive: 0.011102714780143906
# Effective Area Scaler: 0.9999955330325839
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.005551332592339376
# Walkscore Positive: 0.03451101667282064
# Effective Area Scaler: 0.9269671751223288
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00959717389074124
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998949699948123
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04199278846456496
# Effective Area Scaler: 0.18279247556863473
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.002302789727840351
# Walkscore Positive: 0.01027116508307494
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009757601057703357
# Walkscore Positive: 0.0
# Effective Area Scaler: 9.114221566482556e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.08070558276212815
# Effective Area Scaler: 0.9994255697458401
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.024197766910112994
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0020354731057540742
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0006106415705569654
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.020538892273559865
# Effective Area Scaler: 0.9999341795644161
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.002053754039472401
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999975075408467
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02101783353634228
# Effective Area Scaler: 0.999777532641928
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.010506578877221527
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.999866820014867
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.03253574751314013
# Effective Area Scaler: 4.012644937992351e-05
# Slope Scaler: 0.9
# Business Density Scaler: 1.3756969667155146
# Public Amenity Density Scaler: 1.148128184890755
# Calculated Walkscore: 1.855868451961933e-06
# Walkscore Positive: 0.026056436772025973
# Effective Area Scaler: 0.5923313482106723
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.013890639890466256
# Walkscore Positive: 0.04638937383362084
# Effective Area Scaler: 0.0006772434933609047
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 2.8275211430915683e-05
# Walkscore Positive: 0.03065473101354548
# Effective Area Scaler: 0.17333615847512185
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.049469998593882
# Calculated Walkscore: 0.00557643577729757
# Walkscore Positive: 0.08068213321868038
# Effective Area Scaler: 0.9965873386007623
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.08040679241703684
# Walkscore Positive: 0.02407981784411399
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.022875813421809894
# Walkscore Positive: 0.0007922059776183415
# Effective Area Scaler: 0.9914044825228312
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0007461267294275951
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998947703271741
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04231137094398955
# Effective Area Scaler: 0.01760522816958599
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0007076562726550807
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.16156746117009205
# Effective Area Scaler: 7.922299420706879e-05
# Slope Scaler: 0.95
# Business Density Scaler: 1.3753295133049261
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.6723821402528954e-05
# Walkscore Positive: 0.02427810901386379
# Effective Area Scaler: 0.9994212844300945
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012132029447084802
# Walkscore Positive: 0.00020945493434742677
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00018850932941720506
# Walkscore Positive: 0.06873948343619132
# Effective Area Scaler: 0.9255915031733825
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.060443447711012836
# Walkscore Positive: 0.11601778125281344
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0164938007232713
# Calculated Walkscore: 0.11203472138238739
# Walkscore Positive: 0.10963156683591235
# Effective Area Scaler: 6.091977843569656e-08
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 6.344794223141937e-09
# Walkscore Positive: 0.13952369367632556
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0329126370314592
# Calculated Walkscore: 0.13690991606884564
# Walkscore Positive: 0.02881531686921762
# Effective Area Scaler: 0.004939903458651968
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 4.270346503932016e-05
# Walkscore Positive: 0.12992890914030414
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.038978649687830574
# Walkscore Positive: 0.04528588901460287
# Effective Area Scaler: 0.9265842165354599
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012588356997812276
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02087809493852969
# Effective Area Scaler: 0.9997861313832046
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.010436814884621932
# Walkscore Positive: 0.017856735909469686
# Effective Area Scaler: 0.9999185498475387
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.005356584442682219
# Walkscore Positive: 0.0656519181853109
# Effective Area Scaler: 0.9989441239285421
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0459078185270976
# Walkscore Positive: 0.01873575282554445
# Effective Area Scaler: 0.999380382799622
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0131069006815822
# Walkscore Positive: 0.028827173220781047
# Effective Area Scaler: 0.9993933753018969
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0028809685945528824
# Walkscore Positive: 0.04995759900020175
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.002497878472618185
# Walkscore Positive: 0.061091476170647765
# Effective Area Scaler: 0.9270315765149407
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0538020410927955
# Walkscore Positive: 0.04637113308702727
# Effective Area Scaler: 0.547997161946272
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0076233747983771435
# Walkscore Positive: 0.031193604302417105
# Effective Area Scaler: 0.6619336789360665
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.018583287529657377
# Walkscore Positive: 0.02206726057814356
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02206724752627848
# Walkscore Positive: 0.042753259028456295
# Effective Area Scaler: 0.00011315765655700391
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 4.837858601834684e-06
# Walkscore Positive: 0.026262682407268194
# Effective Area Scaler: 0.9998633029638198
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02625909237642098
# Walkscore Positive: 0.03327489272381202
# Effective Area Scaler: 0.2713461337240681
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.004514506745344758
# Walkscore Positive: 0.03969330254334395
# Effective Area Scaler: 0.001032670371116218
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0164459020270995
# Calculated Walkscore: 4.1664216595307634e-05
# Walkscore Positive: 0.010459515903209829
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.007321656801789417
# Walkscore Positive: 0.04921547116864701
# Effective Area Scaler: 0.39452700613323716
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009708416247801478
# Walkscore Positive: 0.027856993704494407
# Effective Area Scaler: 0.9031033406621222
# Slope Scaler: 1.0
# Business Density Scaler: 1.3764225671242412
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03462768668322397
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9998673061481191
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04368724225785637
# Effective Area Scaler: 7.40512702899222e-09
# Slope Scaler: 0.9
# Business Density Scaler: 1.0939729270908514
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 3.1851964844652637e-10
# Walkscore Positive: 0.03536040203155145
# Effective Area Scaler: 0.9935644762641701
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.017566419662484456
# Walkscore Positive: 0.01707848468981308
# Effective Area Scaler: 0.5508822058180683
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.008467409986158905
# Walkscore Positive: 0.030389477149461195
# Effective Area Scaler: 0.9999339632540883
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009116241098184086
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9641401131472307
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.03495802354593893
# Effective Area Scaler: 0.6256592745179259
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01968463048529945
# Walkscore Positive: 0.13697978535631222
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.041093911301543155
# Walkscore Positive: 0.03215844048977672
# Effective Area Scaler: 0.008148744786132759
# Slope Scaler: 0.95
# Business Density Scaler: 1.2814485413283982
# Public Amenity Density Scaler: 1.0164397512458176
# Calculated Walkscore: 0.00032425905554252574
# Walkscore Positive: 0.06571324711092957
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.003285660412214111
# Walkscore Positive: 0.22690415460083826
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.032947716719294
# Calculated Walkscore: 0.16406599284808482
# Walkscore Positive: 0.09580875064180955
# Effective Area Scaler: 0.9925758468655885
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0903425792151567
# Walkscore Positive: 0.02505604572353654
# Effective Area Scaler: 0.9997860141264113
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.017535478858592597
# Walkscore Positive: 0.035470828659974536
# Effective Area Scaler: 0.9350987400802481
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009950618156863362
# Walkscore Positive: 0.03782733440792784
# Effective Area Scaler: 0.9811491268532609
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.011134276837657414
# Walkscore Positive: 0.030120669975540217
# Effective Area Scaler: 0.9529931595577797
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.028704792447987224
# Walkscore Positive: 0.020876654435782262
# Effective Area Scaler: 0.9997862182766183
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01878497224975668
# Walkscore Positive: 0.03465150159578957
# Effective Area Scaler: 0.9954598775138722
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0034494179534216435
# Walkscore Positive: 0.13574771785684867
# Effective Area Scaler: 0.9997932000765225
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.013571964523918362
# Walkscore Positive: 0.03626793453007748
# Effective Area Scaler: 0.9001148588018705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0032645306768576176
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9995595654023572
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.012066723632941102
# Effective Area Scaler: 0.9998950966609961
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012065457793341169
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999980385385019
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 1.0129782981748284e-15
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04012171392513893
# Effective Area Scaler: 0.9199266330517337
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.018454516601708958
# Walkscore Positive: 0.02504846649414191
# Effective Area Scaler: 0.9998312205339603
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.025044238827341917
# Walkscore Positive: 0.1655187092958806
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.11586302797892291
# Walkscore Positive: 0.0208802902902677
# Effective Area Scaler: 0.999614344177246
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.020872237684736467
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999344514744832
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.023009306643677133
# Effective Area Scaler: 0.0010007630774273267
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 2.3026864526195362e-05
# Walkscore Positive: 0.09135737555653113
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0456786607612252
# Walkscore Positive: 0.0
# Effective Area Scaler: 9.413046860247854e-24
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.002000158920362468
# Effective Area Scaler: 0.16417988648270052
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 9.851575934774122e-05
# Walkscore Positive: 0.03332181612428874
# Effective Area Scaler: 0.9746132532619949
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.009742765085247315
# Walkscore Positive: 0.03403510790428574
# Effective Area Scaler: 0.9997859135098787
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03232643037511893
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999169524641079
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# ...
# Walkscore Positive: 0.02072342235130612
# Effective Area Scaler: 3.165119951965849e-14
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 6.559211755713404e-17
# Walkscore Positive: 0.045066961741697394
# Effective Area Scaler: 0.001861740094961509
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 7.551267266935296e-05
# Walkscore Positive: 0.03948271607618105
# Effective Area Scaler: 0.9249061841932316
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03286602744084484
# Walkscore Positive: 0.027663865899818944
# Effective Area Scaler: 0.04844412904522389
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0006700759447702988
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999096448497679
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.03438204156960415
# Effective Area Scaler: 0.25208193016025904
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.006066963981201254
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999139574224455
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.025070692209700155
# Effective Area Scaler: 0.9998073579635717
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.012532931270249105
# Walkscore Positive: 0.060244095401758
# Effective Area Scaler: 0.9892366660401393
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01787870042515175
# Walkscore Positive: 0.06374436997369126
# Effective Area Scaler: 3.240451406911145e-05
# Slope Scaler: 0.9
# Business Density Scaler: 1.3755131759815393
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 2.557140617518522e-06
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999333842627506
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.020989976668011286
# Effective Area Scaler: 0.9754129978714061
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01842650646029618
# Walkscore Positive: 0.06329358356952908
# Effective Area Scaler: 0.9967990548943149
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.05993643506883187
# Walkscore Positive: 0.03538833679910726
# Effective Area Scaler: 9.620161119026435e-13
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 3.40441501741784e-14
# Walkscore Positive: 0.0
# Effective Area Scaler: 8.130262347250114e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02445590861029063
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01711912590194784
# Walkscore Positive: 0.021036792093384705
# Effective Area Scaler: 0.998731494838512
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.010505053407016548
# Walkscore Positive: 0.027533300499699855
# Effective Area Scaler: 0.5725742533520287
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.004729457692779805
# Walkscore Positive: 0.0025293026643679654
# Effective Area Scaler: 3.68981890973442e-15
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 9.33266879942657e-18
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.006261635870849041
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.04192795149896222
# Effective Area Scaler: 3.690976503051817e-15
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.5475508380376575e-16
# Walkscore Positive: 0.06932624714872444
# Effective Area Scaler: 0.9895221685497478
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.06173987257441942
# Walkscore Positive: 0.021066816361963198
# Effective Area Scaler: 0.3086975955712881
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00032516377786399555
# Walkscore Positive: 0.20964929056788784
# Effective Area Scaler: 0.00929352882813798
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0017535435531222075
# Walkscore Positive: 0.04448164818063932
# Effective Area Scaler: 0.9998941116713965
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.04225309118859695
# Walkscore Positive: 0.007384639112203336
# Effective Area Scaler: 9.719367462935434e-22
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 6.818532005703605e-24
# Walkscore Positive: 0.019411296379019356
# Effective Area Scaler: 0.893532501150041
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00520338726123297
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 8.362985675302798e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.021000669062451162
# Effective Area Scaler: 0.9998275536274462
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.006299114271975042
# Walkscore Positive: 0.007291240235297507
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.007291235922832737
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.999786643238246
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 2.374324249018652e-23
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.011273150793550771
# Effective Area Scaler: 0.7931454384085866
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.008494185721977085
# Walkscore Positive: 0.0039722205840334885
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0001986109117315269
# Walkscore Positive: 0.019025747395660302
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.05
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0009512868071361764
# Walkscore Positive: 0.03603124614911477
# Effective Area Scaler: 1.4179609745347998e-06
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.5327270270990608e-08
# Walkscore Positive: 0.025093092452607765
# Effective Area Scaler: 0.5450471938143704
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01367691962541842
# Walkscore Positive: 0.06536804862260276
# Effective Area Scaler: 4.642871646344837e-09
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 2.7314591357409575e-10
# Walkscore Positive: 0.020936362600272197
# Effective Area Scaler: 0.9997825870717698
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.018838629687935506
# Walkscore Positive: 0.02510206151695803
# Effective Area Scaler: 0.998871770916431
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02256636657698735
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999334124969541
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0387850442710721
# Effective Area Scaler: 0.999776486287008
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.038776375281818515
# Walkscore Positive: 0.07409454640403008
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.02446269711507215
# Effective Area Scaler: 0.03928231095650294
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0009609512749090116
# Walkscore Positive: 0.04909517524099031
# Effective Area Scaler: 0.0002623146270402296
# Slope Scaler: 0.9
# Business Density Scaler: 1.6564299221213223
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.919892443283089e-05
# Walkscore Positive: 0.007653208033729417
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0007653203507175778
# Walkscore Positive: 0.02099447498022133
# Effective Area Scaler: 0.999778993688176
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02098983506873727
# Walkscore Positive: 0.035402240960279115
# Effective Area Scaler: 0.042459795083567835
# Slope Scaler: 0.5
# Business Density Scaler: 1.0938593836673793
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0008221293422201768
# Walkscore Positive: 0.13308536586773
# Effective Area Scaler: 7.194692157290549e-18
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 9.575082380587004e-19
# Walkscore Positive: 0.020916128899855568
# Effective Area Scaler: 0.06973122935047991
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0004375522144320089
# Walkscore Positive: 0.0
# Effective Area Scaler: 5.889534800551328e-13
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 2.478553774505482e-27
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.021469759158879873
# Effective Area Scaler: 0.9902473001637841
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00637811131267424
# Walkscore Positive: 0.05619917528500631
# Effective Area Scaler: 0.9618096479515897
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.05135026354623952
# Walkscore Positive: 0.022613194415100527
# Effective Area Scaler: 0.707219590923503
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.015192869398534982
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.904721348754172
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.016546942774057886
# Effective Area Scaler: 0.9998150905177567
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.011580718161205778
# Walkscore Positive: 0.012552769229218209
# Effective Area Scaler: 0.5433050140854091
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.006819982462891289
# Walkscore Positive: 0.13259458847916722
# Effective Area Scaler: 0.9917288918109629
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.03944936528777255
# Walkscore Positive: 0.04537277800673574
# Effective Area Scaler: 0.39460235006706473
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.016113784347476238
# Walkscore Positive: 0.028412556220632157
# Effective Area Scaler: 0.017815101663434564
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.000506172577588612
# Walkscore Positive: 0.014406668134015432
# Effective Area Scaler: 0.9983545008418016
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.01294466577635562
# Walkscore Positive: 0.02100511622844227
# Effective Area Scaler: 0.9997783290472705
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.018900414003884144
# Walkscore Positive: 0.07444356438478952
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 0.02
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0014888704070904657
# Walkscore Positive: 0.0
# Effective Area Scaler: 7.804139615222894e-16
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.029134786173359573
# Effective Area Scaler: 0.9982961752888764
# Slope Scaler: 0.9
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.02617663104425169
# Walkscore Positive: 0.02509809790532329
# Effective Area Scaler: 5.910595497961401e-05
# Slope Scaler: 1.0
# Business Density Scaler: 1.093697517646361
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 1.6224423505297554e-06
# Walkscore Positive: 0.0
# Effective Area Scaler: 0.9999994085416705
# Slope Scaler: 1.0
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0
# Walkscore Positive: 0.0367843901229652
# Effective Area Scaler: 0.9012078141724293
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.023205265872868357
# Walkscore Positive: 0.012554588086281099
# Effective Area Scaler: 0.999893296280632
# Slope Scaler: 0.7
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.008787273925526012
# Walkscore Positive: 0.01927002558055787
# Effective Area Scaler: 0.9839647302834803
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.001896102552292939
# Walkscore Positive: 0.010003472532171211
# Effective Area Scaler: 0.9830294970820077
# Slope Scaler: 0.1
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.0009833708572373945
# Walkscore Positive: 0.044717643595096675
# Effective Area Scaler: 0.0195072462128549
# Slope Scaler: 0.5
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00043615904183412236
# Walkscore Positive: 0.021358107962015926
# Effective Area Scaler: 0.999876473160064
# Slope Scaler: 0.3
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00640664089872971
# Walkscore Positive: 0.021503027738749802
# Effective Area Scaler: 0.01386695806166335
# Slope Scaler: 0.95
# Business Density Scaler: 1.0
# Public Amenity Density Scaler: 1.0
# Calculated Walkscore: 0.00028327250465942584
# Walkscore Positive: 0.0049128977757630565
# Effective Area Scaler: 0.9946898599893738
# Slope Scaler: 0.3
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
min_walkscore, max_walkscore = None, None
with arcpy.da.SearchCursor(walkscore_fishnet, [walkscore_field]) as cursor:
    for row in cursor:
        if min_walkscore is None or row[0] < min_walkscore:
            min_walkscore = row[0]
        if max_walkscore is None or row[0] > max_walkscore:
            max_walkscore = row[0]

# Normalize the scaled walkscore field to a scale of 0-100
with arcpy.da.UpdateCursor(walkscore_fishnet, [walkscore_field]) as cursor:
    for row in cursor:
        if max_walkscore > min_walkscore:
            row[0] = ((row[0] - min_walkscore) / (max_walkscore - min_walkscore)) * 100
        else:
            row[0] = 0
        cursor.updateRow(row)

print("Scaled walkscore normalization to 0-100 scale complete.")
# Out:
# Scaled walkscore normalization to 0-100 scale complete.

# %% [markdown]
# ### Aggregating Walkscore by Neighborhood

# %%
# # Set environment settings
# arcpy.env.workspace = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb"
# arcpy.env.overwriteOutput = True  # Allow outputs to be overwritten

# # Define the input layers
# walkscore_fishnet = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb\walkscore_fishnet"
# neighborhoods = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb\neighborhoods"
# clipped_walkscore_fishnet = "walkscore_fishnet_clipped"
# spatial_join_output = "walkscore_neighborhoods_join"
# statistics_output = "walkscore_statistics"
# output_layer = "walkscore_neighborhoods"

# # Step 1: Ensure the spatial reference systems match
# walkscore_sr = arcpy.Describe(walkscore_fishnet).spatialReference
# neighborhoods_sr = arcpy.Describe(neighborhoods).spatialReference

# if walkscore_sr.name != neighborhoods_sr.name:
#     raise ValueError("Spatial references do not match between walkscore_fishnet and neighborhoods.")

# # Step 2: Clip the walkscore fishnet to the neighborhoods layer
# arcpy.analysis.Clip(walkscore_fishnet, neighborhoods, clipped_walkscore_fishnet)
# print("Clipped walkscore fishnet to neighborhoods layer.")

# # Step 3: Perform a spatial join to associate each fishnet cell with a neighborhood
# arcpy.analysis.SpatialJoin(target_features=clipped_walkscore_fishnet,
#                            join_features=neighborhoods,
#                            out_feature_class=spatial_join_output,
#                            join_type="KEEP_COMMON",
#                            match_option="INTERSECT")
# print("Performed spatial join between neighborhoods and clipped walkscore fishnet.")

# # Step 4: Calculate the total walkscore and total area for each neighborhood
# arcpy.analysis.Statistics(spatial_join_output, statistics_output,
#                           [["walk_score", "SUM"], ["total_area", "SUM"]],
#                           "nested")
# print("Calculated total walkscore and total area for each neighborhood.")

# # Step 5: Add a field for the area-normalized average walkscore
# area_normalized_walkscore_field = "area_normalized_walk_score"

# # Delete the existing field if it exists
# if any(f.name == area_normalized_walkscore_field for f in arcpy.ListFields(neighborhoods)):
#     arcpy.management.DeleteField(neighborhoods, area_normalized_walkscore_field)

# arcpy.management.AddField(neighborhoods, area_normalized_walkscore_field, "DOUBLE")

# # Step 6: Join the statistics table to the neighborhoods layer
# arcpy.management.JoinField(in_data=neighborhoods,
#                            in_field="nested",
#                            join_table=statistics_output,
#                            join_field="nested",
#                            fields=["SUM_walk_score", "SUM_total_area"])
# print("Joined the statistics table to the neighborhoods layer.")

# # Step 7: Calculate the area-normalized average walkscore for each neighborhood
# with arcpy.da.UpdateCursor(neighborhoods, ["SUM_walk_score", "SUM_total_area", area_normalized_walkscore_field]) as cursor:
#     for row in cursor:
#         if row[0] is not None and row[1] is not None and row[1] != 0:
#             row[2] = row[0] / row[1]  # SUM_walk_score / SUM_total_area
#         else:
#             row[2] = None
#         cursor.updateRow(row)
# print("Calculated area-normalized average walkscore for each neighborhood.")

# # Step 8: Normalize the area-normalized walkscores to be between 0 and 10
# # Step 8.1: Calculate min and max of area-normalized walkscore
# scores = [row[0] for row in arcpy.da.SearchCursor(neighborhoods, [area_normalized_walkscore_field]) if row[0] is not None]
# min_score = min(scores)
# max_score = max(scores)
# print(f"Min score: {min_score}, Max score: {max_score}")

# # Step 8.2: Add a new field for the normalized walkscore
# normalized_walkscore_field = "normalized_walk_score"

# # Delete the existing field if it exists
# if any(f.name == normalized_walkscore_field for f in arcpy.ListFields(neighborhoods)):
#     arcpy.management.DeleteField(neighborhoods, normalized_walkscore_field)

# arcpy.management.AddField(neighborhoods, normalized_walkscore_field, "DOUBLE")

# # Step 8.3: Normalize the walkscore to be between 0 and 10
# with arcpy.da.UpdateCursor(neighborhoods, [area_normalized_walkscore_field, normalized_walkscore_field]) as cursor:
#     for row in cursor:
#         if row[0] is not None:
#             row[1] = 10 * (row[0] - min_score) / (max_score - min_score)
#         else:
#             row[1] = None
#         cursor.updateRow(row)
# print("Normalized area-normalized walkscores to be between 0 and 10.")

# # Step 9: Export the joined layer to a new feature class
# arcpy.conversion.FeatureClassToFeatureClass(in_features=neighborhoods,
#                                             out_path=arcpy.env.workspace,
#                                             out_name=output_layer)
# print("Exported the joined layer to a new feature class with normalized walkscores.")

# # Step 10: Clean up temporary fields
# fields_to_delete = ["SUM_walk_score", "SUM_total_area", area_normalized_walkscore_field, normalized_walkscore_field]
# for field in fields_to_delete:
#     if any(f.name == field for f in arcpy.ListFields(neighborhoods)):
#         arcpy.management.DeleteField(neighborhoods, field)
#         print(f"Deleted temporary field: {field}")

# print("Temporary fields cleaned up.")

# %% [markdown]
# #### Smoothing the Walkscore Fishnet

# %% [markdown]
# ### Adjust Symbology
#
# Now that we have a field that aggregates the walkscore for each component, let's programmatically change the symology of the walkscore_fishnet layer so that we can visually identify which areas have the best walkscore.

# %%
# import arcpy
# import os

# aprx_path = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.aprx"
# walkscore_field = 'walk_score'  # The field used to color the fishnet grid
# walkscore_fishnet_layer_path = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.gdb\walkscore_fishnet"

# # Check if the project file is writable
# if os.access(aprx_path, os.W_OK):
#     print(f"The project file {aprx_path} is writable.")
# else:
#     print(f"The project file {aprx_path} is not writable. Please check permissions.")

# # Open the ArcGIS Pro project
# aprx = arcpy.mp.ArcGISProject(aprx_path)
# print("Successfully opened the ArcGIS Pro project.")

# # Specify the map name if it's just "Map"
# map_name = "Map"
# m = aprx.listMaps(map_name)[0]

# # Find the walkscore_fishnet layer in the map
# walkscore_layer = None
# for lyr in m.listLayers():
#     if lyr.isFeatureLayer and lyr.name == "walkscore_fishnet":
#         walkscore_layer = lyr
#         break

# # If the walkscore_fishnet layer is not found, add it to the map
# if walkscore_layer is None:
#     print("walkscore_fishnet layer not found in the map. Adding it now.")
#     walkscore_layer = m.addDataFromPath(walkscore_fishnet_layer_path)
#     walkscore_layer.name = "walkscore_fishnet"

# # Apply a graduated color renderer to the walkscore_fishnet layer
# sym = walkscore_layer.symbology
# if hasattr(sym, 'renderer') and sym.renderer.type == 'GraduatedColorsRenderer':
#     sym.updateRenderer('GraduatedColorsRenderer')
#     sym.renderer.classificationField = walkscore_field
#     sym.renderer.breakCount = 5  # You can adjust the number of classes here
#     color_ramp_name = "Greens (Continuous)"
#     color_ramps = aprx.listColorRamps("*")
#     greens_ramp = next((ramp for ramp in color_ramps if ramp.name == color_ramp_name), None)
#     if greens_ramp is not None:
#         sym.renderer.colorRamp = greens_ramp
#         walkscore_layer.symbology = sym
#         print(f"Applied graduated color renderer to {walkscore_layer.name} based on {walkscore_field} using {color_ramp_name}.")
#     else:
#         print(f"Color ramp {color_ramp_name} not found.")
# else:
#     print(f"{walkscore_layer.name} does not support graduated color renderer.")

# # Try to save the project using saveACopy
# try:
#     new_aprx_path = r"C:\Users\rtvpd\OneDrive\Documentos\ArcGIS\Projects\Walkability_Seattle\Walkability_Seattle.aprx"
#     aprx.saveACopy(new_aprx_path)
#     print(f"Project saved with updated layer symbology to {new_aprx_path}.")
# except OSError as e:
#     print(f"Failed to save the project: {e}")
# except Exception as e:
#     print(f"An unexpected error occurred: {e}")

# %%
# This is where I left off, the fishnet walkscore layer isn't updating with the changed symobology above. Need to troubleshoot.
